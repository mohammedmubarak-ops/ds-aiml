# %%
import pandas as pd
# 1d -> method series
df = pd.Series([10,20,30])
print(df)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
#example 2
import pandas as pd
d = {"name": "kunal","age":"21","roll no":123}
df = pd.Series(data=d,index=["name","age","roll no"])
print(df)
# Out:
# name       kunal
# age           21
# roll no      123
# dtype: object

# %%
import pandas as pd
d = {
    "name": ["kunal","dheeraj","anjali","praveen","yash","danish"],
    "roll no": [12,13,14,15,16,17]
}
df = pd.DataFrame(data=d)
print(df)
# Out:
#       name  roll no
# 0    kunal       12
# 1  dheeraj       13
# 2   anjali       14
# 3  praveen       15
# 4     yash       16
# 5   danish       17

# %%
#CSV
import pandas as pd
url = "https://raw.githubusercontent.com/mohammedmubarak-ops/ds-aiml/main/file2%20-%20Sheet1.csv"
df = pd.read_csv(url)
print(df)
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
